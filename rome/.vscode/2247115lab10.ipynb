# %%
import pandas as pd

df = pd.read_csv (r'E:\Salaries.csv')
print (df)
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
import numpy as np
import csv

with open('E:\Salaries.csv','r') as x:
    f = list(csv.reader(x, delimiter=","))
f=np.array(f)
display(f)
# Out:
# array([['work_year', 'experience_level', 'employment_type', ...,
#         'remote_ratio', 'company_location', 'company_size'],
#        ['2020', 'MI', 'FT', ..., '0', 'DE', 'L'],
#        ['2020', 'SE', 'FT', ..., '0', 'JP', 'S'],
#        ...,
#        ['2022', 'SE', 'FT', ..., '0', 'US', 'M'],
#        ['2022', 'SE', 'FT', ..., '100', 'US', 'M'],
#        ['2022', 'MI', 'FT', ..., '100', 'US', 'L']], dtype='<U40')

# %%
import numpy as np
import csv

with open('E:\Salaries.csv') as y:
    j = csv.reader(y)
    d=pd.DataFrame([j])

for index, row in df.iterrows():
    print(row)
# Out:
# work_year                       2020
# experience_level                  MI
# employment_type                   FT
# job_title             Data Scientist
# salary                         70000
# salary_currency                  EUR
# salary_in_usd                  79833
# employee_residence                DE
# remote_ratio                       0
# company_location                  DE
# company_size                       L
# Name: 0, dtype: object
# work_year                                   2020
# experience_level                              SE
# employment_type                               FT
# job_title             Machine Learning Scientist
# salary                                    260000
# salary_currency                              USD
# salary_in_usd                             260000
# employee_residence                            JP
# remote_ratio                                   0
# company_location                              JP
# ...
